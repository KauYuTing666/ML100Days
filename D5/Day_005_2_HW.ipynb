# %% [markdown]
# <a href="https://colab.research.google.com/github/KauYuTing666/ML100Days/blob/master/D5/Day_005_2_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 讀取 txt 檔
# * 請讀取 [text file](https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt)
# * 懶人複製連結: https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt
#
# ### Hints: 使用 [Request](https://blog.gtwang.org/programming/python-requests-module-tutorial/) 抓取資料
# ### Hints: [字串分割](http://www.runoob.com/python/att-string-split.html)
# ### Hints: 例外處理: [Try-Except](https://pydoing.blogspot.com/2011/01/python-try.html)

# %% [markdown]
# # [作業目標]
# - 試著讀取網頁上的圖片連結清單, 再以清單中網址讀取圖片

# %% [markdown]
# # [作業重點]
# - 從網頁上讀取連結清單 (In[1], In[2])
# - 從清單網址讀取圖片 (In[6]~In[9], Out[6]~Out[9])

# %%
## 假如我們不想把資料載到自己的電腦裡?
# 把連結填入
target_url = 'https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt'

# %%
import requests
response = requests.get(target_url)
data = response.text

# 用 request 傳送回來的資料不會認得斷行符號
print(len(data))
data[0:100]
# Out:
# 784594
# 'n00015388_157\thttp://farm1.static.flickr.com/145/430300483_21e993670c.jpg\nn00015388_238\thttp://farm2'

# %%
# 找到換行符號，用該符號做字串分割後，把它拿掉
split_tag = '\n'

data = data.split(split_tag)
print(len(data))
data[0]
# Out:
# 9996
# 'n00015388_157\thttp://farm1.static.flickr.com/145/430300483_21e993670c.jpg'

# %% [markdown]
# ## 將 txt 轉成 pandas dataframe

# %%
import pandas as pd

arrange_data = []
for line in data:
    line = line.split('\t')
    arrange_data.append(line)

df = pd.DataFrame(arrange_data)
df.head()
# Out:
#                0                                                  1
# 0  n00015388_157  http://farm1.static.flickr.com/145/430300483_2...
# 1  n00015388_238  http://farm2.static.flickr.com/1005/3352960681...
# 2  n00015388_304  http://farm1.static.flickr.com/27/51009336_a96...
# 3  n00015388_327  http://farm4.static.flickr.com/3025/2444687979...
# 4  n00015388_355  http://img100.imageshack.us/img100/3253/forres...

# %% [markdown]
# ## 讀取圖片，請讀取上面 data frame 中的前 5 張圖片

# %%
from PIL import Image
from io import BytesIO
import numpy as np
import matplotlib.pyplot as plt

# 請用 df.loc[...] 得到第一筆資料的連結
first_link = df.loc[0][1]

response = requests.get(first_link)
img = Image.open(BytesIO(response.content))

# Convert img to numpy array

plt.imshow(img)
plt.show()

# %%
def img2arr_fromURLs(url_list, resize = False):
    """
    請完成這個 Function
    Args
        - url_list: list of URLs
        - resize: bool
    Return
        - list of array
    """
    img_list = []
    for i,url in enumerate(url_list):
      try:
        response = requests.get(url)
        if response.status_code == 200:
          print(f"第{i+1}連結訪問成功")
          img = Image.open(BytesIO(response.content))
          img_list.append(img)
        else:
          print(f"第{i+1}連結訪問失敗，HTTP狀態碼:{response.status_code}")
      except Exception as e:
        print(f"第{i+1}連結請求失敗，錯誤訊息{e}")
    return img_list

# %%
result = img2arr_fromURLs(df[0:5][1].values)
print(result)
print("Total images that we got: %i " % len(result)) # 如果不等於 5, 代表有些連結失效囉

for im_get in result:
    plt.imshow(im_get)
    plt.show()
# Out:
# 第1連結訪問成功
# 第2連結訪問成功
# 第3連結訪問成功
# 第4連結訪問成功
# 第5連結訪問失敗，HTTP狀態碼:404
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=499x435 at 0x78E1ACB363B0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x322 at 0x78E1ACB37640>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=375x500 at 0x78E1ACB351E0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375 at 0x78E1ACB373D0>]
# Total images that we got: 4
