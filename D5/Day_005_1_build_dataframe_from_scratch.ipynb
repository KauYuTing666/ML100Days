# %% [markdown]
# <a href="https://colab.research.google.com/github/KauYuTing666/ML100Days/blob/master/D5/Day_005_1_build_dataframe_from_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [教學目標]
# - Pandas 處理最常用的資料格式, 我們稱為 DataFrame, 試著使用不同的方式新建一個 DataFrame 吧
# - 練習看看 DataFrame 可以對資料做什麼操作? (groupby 的使用)

# %% [markdown]
# # [範例重點]
# - 新建 DataFrame 方法一 (In[2], In[3])
# - 新建 DataFrame 方法二 (In[4], In[5])
# - 資料操作 : groupby (In[6], Out[6])

# %%
import pandas as pd

# %% [markdown]
# ### 方法一
# 直接將dict轉為df

# %%
data = {'weekday': ['Sun', 'Sun', 'Mon', 'Mon'],
        'city': ['Austin', 'Dallas', 'Austin', 'Dallas'],
        'visitor': [139, 237, 326, 456]}

# %%
visitors_1 = pd.DataFrame(data)
print(visitors_1)
# Out:
#   weekday    city  visitor
# 0     Sun  Austin      139
# 1     Sun  Dallas      237
# 2     Mon  Austin      326
# 3     Mon  Dallas      456

# %%
visitors_1
# Out:
#   weekday    city  visitor
# 0     Sun  Austin      139
# 1     Sun  Dallas      237
# 2     Mon  Austin      326
# 3     Mon  Dallas      456

# %% [markdown]
# ### 方法二
# 將list組合成dict，再將dict轉為df

# %%
cities = ['Austin', 'Dallas', 'Austin', 'Dallas']
weekdays = ['Sun', 'Sun', 'Mon', 'Mon']
visitors = [139, 237, 326, 456]

list_labels = ['city', 'weekday', 'visitor']
list_cols = [cities, weekdays, visitors]

zipped = list(zip(list_labels, list_cols))
list(zip(list_labels, list_cols))
# Out:
# [('city', ['Austin', 'Dallas', 'Austin', 'Dallas']),
#  ('weekday', ['Sun', 'Sun', 'Mon', 'Mon']),
#  ('visitor', [139, 237, 326, 456])]

# %%
visitors_2 = pd.DataFrame(dict(zipped))
visitors_2
# Out:
#      city weekday  visitor
# 0  Austin     Sun      139
# 1  Dallas     Sun      237
# 2  Austin     Mon      326
# 3  Dallas     Mon      456

# %% [markdown]
# ## 一個簡單例子
# 假設你想知道如果利用 pandas 計算上述資料中，每個 weekday 的平均 visitor 數量，
#
# 通過 google 你找到了 https://stackoverflow.com/questions/30482071/how-to-calculate-mean-values-grouped-on-another-column-in-pandas
#
# 想要測試的時候就可以用 visitors_1 這個只有 4 筆資料的資料集來測試程式碼

# %%
visitors_1.groupby(by="weekday")['visitor'].mean()

## 如果想找的是weekday的最大visitor數量
visitors_1.groupby(by="weekday")['visitor'].max()
# Out:
# weekday
# Mon    456
# Sun    237
# Name: visitor, dtype: int64

# %% [markdown]
# ## 練習時間
# 在小量的資料上，我們用眼睛就可以看得出來程式碼是否有跑出我們理想中的結果
#
# 請嘗試想像一個你需要的資料結構 (裡面的值可以是隨機的)，然後用上述的方法把它變成 pandas DataFrame
#
# #### Ex: 想像一個 dataframe 有兩個欄位，一個是國家，一個是人口，求人口數最多的國家
#
# ### Hints: [隨機產生數值](https://blog.csdn.net/christianashannon/article/details/78867204)

# %%
country = ['Taiwan', 'China', 'Thailand', 'USA', 'Japan']
population = [23000000, 1400000000, 69000000, 328000000, 126800000]

list_labels = ['country', 'population']
list_cols = [country, population]

zipped = list(zip(list_labels, list_cols))
df = pd.DataFrame(dict(zipped))
df
# Out:
#     country  population
# 0    Taiwan    23000000
# 1     China  1400000000
# 2  Thailand    69000000
# 3       USA   328000000
# 4     Japan   126800000

# %%
df[df['population'] == df['population'].max()]
# Out:
#   country  population
# 1   China  1400000000
